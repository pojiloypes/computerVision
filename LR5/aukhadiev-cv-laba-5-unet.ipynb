# %%
import os
import numpy as np
import cv2
from glob import glob
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, CSVLogger, EarlyStopping
import matplotlib.pyplot as plt
from tqdm import tqdm
import urllib
import IPython

# %%
def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

# %%
def encoder_block(inputs, num_filters):
    x = conv_block(inputs, num_filters)
    p = MaxPool2D((2, 2))(x)
    return x, p

# %%
def decoder_block(inputs, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding='same')(inputs)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

# %%
def build_unet(input_shape):
    inputs = Input(input_shape)

    """ Encoder """
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)
    b1 = conv_block(p4, 1024)

    """ Decoder """
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    """ Output """
    outputs = Conv2D(1, (1, 1), padding="same", activation="sigmoid")(d4)
    return Model(inputs, outputs, name="U-Net")

# %%
def load_data(dataset_path):
    images = sorted(glob(os.path.join(dataset_path, "images/*")))
    masks = sorted(glob(os.path.join(dataset_path, "masks/*")))
    train_x, test_x = train_test_split(images, test_size=0.2, random_state=42)
    train_y, test_y = train_test_split(masks, test_size=0.2, random_state=42)
    return (train_x, train_y), (test_x, test_y)

# %%
def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (256, 256))
    x = x/255.0
    x = x.astype(np.float32)
    # (256, 256, 3)
    return x

# %%
def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (256, 256))
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=-1)
    return x

# %%
def preprocess(image_path, mask_path):
    def f(image_path, mask_path):
        image_path = image_path.decode()
        mask_path = mask_path.decode()
        x = read_image(image_path)
        y = read_mask(mask_path)
        return x, y
    image, mask = tf.numpy_function(f, [image_path, mask_path], [tf.float32, tf.float32])
    image.set_shape([256, 256, 3])
    mask.set_shape([256, 256, 1])
    return image, mask

# %%
def tf_dataset(images, masks, batch=8):
    dataset = tf.data.Dataset.from_tensor_slices((images, masks))
    dataset = dataset.shuffle(buffer_size=5000)
    dataset = dataset.map(preprocess)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(2)
    dataset = dataset.repeat()
    return dataset

# %%
""" Hyperparameters """
dataset_path = "../input/person-segmentation/people_segmentation"
input_shape = (256, 256, 3)
batch_size = 8
epochs = 20
lr = 1e-4
model_path = "./unet.keras"
csv_path = "./data.csv"

""" Loading the dataset """
(train_x, train_y), (test_x, test_y) = load_data(dataset_path)

train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
valid_dataset = tf_dataset(test_x, test_y, batch=batch_size)

# %%
valid_dataset
# Out:
# <_RepeatDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 256, 256, 1), dtype=tf.float32, name=None))>

# %%
""" Model """
model = build_unet(input_shape)
model.compile(
    loss="binary_crossentropy",
    optimizer=tf.keras.optimizers.Adam(lr),
    metrics=[
        tf.keras.metrics.MeanIoU(num_classes=2),
        tf.keras.metrics.Recall(),
        tf.keras.metrics.Precision()
    ]
)

callbacks = [
    ModelCheckpoint(model_path, monitor="val_loss", verbose=1),
    ReduceLROnPlateau(monitor="val_loss", patience=5, factor=0.1, verbose=1),
    CSVLogger(csv_path),
    EarlyStopping(monitor="val_loss", patience=10)
]

train_steps = len(train_x)//batch_size
if len(train_x) % batch_size != 0:
    train_steps += 1
    
valid_steps = len(test_x)//batch_size
if len(test_x) % batch_size != 0:
    valid_steps += 1

model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs = epochs,
    steps_per_epoch=train_steps,
    validation_steps=valid_steps,
    callbacks=callbacks
)
# Out:
# Epoch 1/20
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 0.4482 - mean_io_u_2: 0.2671 - precision_2: 0.6082 - recall_2: 0.5524
# Epoch 1: saving model to ./unet.keras
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 156s 241ms/step - loss: 0.4481 - mean_io_u_2: 0.2671 - precision_2: 0.6084 - recall_2: 0.5525 - val_loss: 0.3494 - val_mean_io_u_2: 0.2500 - val_precision_2: 0.7007 - val_recall_2: 0.7633 - learning_rate: 1.0000e-04
# Epoch 2/20
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.3053 - mean_io_u_2: 0.2664 - precision_2: 0.7734 - recall_2: 0.6915
# Epoch 2: saving model to ./unet.keras
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 129s 227ms/step - loss: 0.3053 - mean_io_u_2: 0.2664 - precision_2: 0.7734 - recall_2: 0.6915 - val_loss: 0.3285 - val_mean_io_u_2: 0.2500 - val_precision_2: 0.6879 - val_recall_2: 0.8007 - learning_rate: 1.0000e-04
# Epoch 3/20
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.2685 - mean_io_u_2: 0.2670 - precision_2: 0.7935 - recall_2: 0.7530
# Epoch 3: saving model to ./unet.keras
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 129s 227ms/step - loss: 0.2685 - mean_io_u_2: 0.2670 - precision_2: 0.7936 - recall_2: 0.7530 - val_loss: 0.3190 - val_mean_io_u_2: 0.2500 - val_precision_2: 0.6656 - val_recall_2: 0.9045 - learning_rate: 1.0000e-04
# Epoch 4/20
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.2416 - mean_io_u_2: 0.2691 - precision_2: 0.8115 - recall_2: 0.7813
# Epoch 4: saving model to ./unet.keras
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 129s 227ms/step - loss: 0.2416 - mean_io_u_2: 0.2690 - precision_2: 0.8115 - recall_2: 0.7813 - val_loss: 0.2320 - val_mean_io_u_2: 0.2500 - val_precision_2: 0.8260 - val_recall_2: 0.7888 - learning_rate: 1.0000e-04
# Epoch 5/20
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.2185 - mean_io_u_2: 0.2676 - precision_2: 0.8300 - recall_2: 0.8125
# Epoch 5: saving model to ./unet.keras
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 129s 227ms/step - loss: 0.2185 - mean_io_u_2: 0.2675 - precision_2: 0.8300 - recall_2: 0.8125 - val_loss: 0.2244 - val_mean_io_u_2: 0.2500 - val_precision_2: 0.8124 - val_recall_2: 0.8253 - learning_rate: 1.0000e-04
# Epoch 6/20
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.2034 - mean_io_u_2: 0.2672 - precision_2: 0.8433 - recall_2: 0.8304
# Epoch 6: saving model to ./unet.keras
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 128s 226ms/step - loss: 0.2034 - mean_io_u_2: 0.2671 - precision_2: 0.8433 - recall_2: 0.8304 - val_loss: 0.2237 - val_mean_io_u_2: 0.2500 - val_precision_2: 0.8781 - val_recall_2: 0.7293 - learning_rate: 1.0000e-04
# Epoch 7/20
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.1902 - mean_io_u_2: 0.2665 - precision_2: 0.8498 - recall_2: 0.8466
# Epoch 7: saving model to ./unet.keras
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 128s 226ms/step - loss: 0.1902 - mean_io_u_2: 0.2665 - precision_2: 0.8498 - recall_2: 0.8466 - val_loss: 0.2257 - val_mean_io_u_2: 0.2500 - val_precision_2: 0.8024 - val_recall_2: 0.8468 - learning_rate: 1.0000e-04
# Epoch 8/20
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.1730 - mean_io_u_2: 0.2658 - precision_2: 0.8693 - recall_2: 0.8628
# Epoch 8: saving model to ./unet.keras
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 128s 226ms/step - loss: 0.1730 - mean_io_u_2: 0.2657 - precision_2: 0.8693 - recall_2: 0.8628 - val_loss: 0.1996 - val_mean_io_u_2: 0.2500 - val_precision_2: 0.8323 - val_recall_2: 0.8486 - learning_rate: 1.0000e-04
# Epoch 9/20
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.1652 - mean_io_u_2: 0.2673 - precision_2: 0.8716 - recall_2: 0.8696
# Epoch 9: saving model to ./unet.keras
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 128s 226ms/step - loss: 0.1652 - mean_io_u_2: 0.2673 - precision_2: 0.8716 - recall_2: 0.8696 - val_loss: 0.1968 - val_mean_io_u_2: 0.2500 - val_precision_2: 0.8386 - val_recall_2: 0.8492 - learning_rate: 1.0000e-04
# Epoch 10/20
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.1523 - mean_io_u_2: 0.2664 - precision_2: 0.8789 - recall_2: 0.8850
# Epoch 10: saving model to ./unet.keras
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 128s 226ms/step - loss: 0.1524 - mean_io_u_2: 0.2663 - precision_2: 0.8789 - recall_2: 0.8850 - val_loss: 0.2102 - val_mean_io_u_2: 0.2500 - val_precision_2: 0.8714 - val_recall_2: 0.7916 - learning_rate: 1.0000e-04
# Epoch 11/20
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - loss: 0.1379 - mean_io_u_2: 0.2665 - precision_2: 0.8929 - recall_2: 0.8959
# Epoch 11: saving model to ./unet.keras
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 128s 226ms/step - loss: 0.1379 - mean_io_u_2: 0.2665 - precision_2: 0.8929 - recall_2: 0.8958 - val_loss: 0.2049 - val_mean_io_u_2: 0.2500 - val_precision_2: 0.8883 - val_recall_2: 0.7791 - learning_rate: 1.0000e-04
# Epoch 12/20
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.1251 - mean_io_u_2: 0.2676 - precision_2: 0.9018 - recall_2: 0.9070
# Epoch 12: saving model to ./unet.keras
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 129s 226ms/step - loss: 0.1251 - mean_io_u_2: 0.2676 - precision_2: 0.9018 - recall_2: 0.9070 - val_loss: 0.1837 - val_mean_io_u_2: 0.2500 - val_precision_2: 0.8870 - val_recall_2: 0.8233 - learning_rate: 1.0000e-04
# Epoch 13/20
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.1122 - mean_io_u_2: 0.2668 - precision_2: 0.9156 - recall_2: 0.9182
# Epoch 13: saving model to ./unet.keras
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 128s 226ms/step - loss: 0.1122 - mean_io_u_2: 0.2668 - precision_2: 0.9156 - recall_2: 0.9182 - val_loss: 0.2002 - val_mean_io_u_2: 0.2500 - val_precision_2: 0.8580 - val_recall_2: 0.8445 - learning_rate: 1.0000e-04
# Epoch 14/20
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.1029 - mean_io_u_2: 0.2664 - precision_2: 0.9217 - recall_2: 0.9250
# Epoch 14: saving model to ./unet.keras
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 128s 226ms/step - loss: 0.1029 - mean_io_u_2: 0.2664 - precision_2: 0.9217 - recall_2: 0.9250 - val_loss: 0.1956 - val_mean_io_u_2: 0.2500 - val_precision_2: 0.8675 - val_recall_2: 0.8497 - learning_rate: 1.0000e-04
# Epoch 15/20
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.0933 - mean_io_u_2: 0.2654 - precision_2: 0.9294 - recall_2: 0.9341
# Epoch 15: saving model to ./unet.keras
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 129s 227ms/step - loss: 0.0933 - mean_io_u_2: 0.2654 - precision_2: 0.9294 - recall_2: 0.9341 - val_loss: 0.2005 - val_mean_io_u_2: 0.2500 - val_precision_2: 0.9107 - val_recall_2: 0.7891 - learning_rate: 1.0000e-04
# Epoch 16/20
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.0860 - mean_io_u_2: 0.2681 - precision_2: 0.9343 - recall_2: 0.9360
# Epoch 16: saving model to ./unet.keras
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 129s 227ms/step - loss: 0.0860 - mean_io_u_2: 0.2681 - precision_2: 0.9343 - recall_2: 0.9360 - val_loss: 0.2096 - val_mean_io_u_2: 0.2502 - val_precision_2: 0.8284 - val_recall_2: 0.8944 - learning_rate: 1.0000e-04
# Epoch 17/20
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.0780 - mean_io_u_2: 0.2669 - precision_2: 0.9381 - recall_2: 0.9452
# Epoch 17: saving model to ./unet.keras
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 129s 227ms/step - loss: 0.0780 - mean_io_u_2: 0.2668 - precision_2: 0.9381 - recall_2: 0.9452 - val_loss: 0.1993 - val_mean_io_u_2: 0.2500 - val_precision_2: 0.8402 - val_recall_2: 0.8845 - learning_rate: 1.0000e-04
# Epoch 18/20
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.0584 - mean_io_u_2: 0.2677 - precision_2: 0.9596 - recall_2: 0.9551
# Epoch 18: saving model to ./unet.keras
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 129s 227ms/step - loss: 0.0584 - mean_io_u_2: 0.2677 - precision_2: 0.9596 - recall_2: 0.9552 - val_loss: 0.1746 - val_mean_io_u_2: 0.2500 - val_precision_2: 0.8893 - val_recall_2: 0.8704 - learning_rate: 1.0000e-05
# Epoch 19/20
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.0468 - mean_io_u_2: 0.2661 - precision_2: 0.9648 - recall_2: 0.9694
# Epoch 19: saving model to ./unet.keras
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 128s 226ms/step - loss: 0.0468 - mean_io_u_2: 0.2661 - precision_2: 0.9648 - recall_2: 0.9694 - val_loss: 0.1808 - val_mean_io_u_2: 0.2500 - val_precision_2: 0.8835 - val_recall_2: 0.8809 - learning_rate: 1.0000e-05
# Epoch 20/20
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.0441 - mean_io_u_2: 0.2680 - precision_2: 0.9666 - recall_2: 0.9699
# Epoch 20: saving model to ./unet.keras
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 129s 226ms/step - loss: 0.0441 - mean_io_u_2: 0.2680 - precision_2: 0.9666 - recall_2: 0.9699 - val_loss: 0.1865 - val_mean_io_u_2: 0.2500 - val_precision_2: 0.8948 - val_recall_2: 0.8629 - learning_rate: 1.0000e-05

# %%
model.save("unet_model.keras")

# %%
# https://raw.githubusercontent.com/nikhilroxtomar/Unet-for-Person-Segmentation/main/images/Black-Widow-Avengers.jpg

#test_images = glob("images/*")


test_images = [
    'https://raw.githubusercontent.com/nikhilroxtomar/Unet-for-Person-Segmentation/main/images/Black-Widow-Avengers.jpg'
]

model = tf.keras.models.load_model("./unet.keras")
for path in tqdm(test_images, total=len(test_images)):
    
    req = urllib.request.urlopen(path)
    imgarr = np.asarray(bytearray(req.read()), dtype=np.uint8)
    
    x = cv2.imdecode(imgarr, -1)
    
    #x = cv2.imread(path, cv2.IMREAD_COLOR)
    original_image = x
    h, w, _ = x.shape
    
    x = cv2.resize(x, (256, 256))
    x = x/255.0
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=0)

    pred_mask = model.predict(x)[0]
    pred_mask = cv2.resize(pred_mask, (w, h))
    pred_mask = np.expand_dims(pred_mask, axis=-1)
    pred_mask = pred_mask > 0.5
    
    background_mask = np.abs(1- pred_mask)
        
    masked_image = original_image * pred_mask
    
    background_mask = np.concatenate([background_mask, background_mask, background_mask], axis=-1)
    background_mask = background_mask * [0, 0, 0]
    
    masked_image = masked_image + background_mask
    name = path.split("/")[-1]
    cv2.imwrite(f"{name}.png", masked_image)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 100%|██████████| 1/1 [00:01<00:00,  1.31s/it]
